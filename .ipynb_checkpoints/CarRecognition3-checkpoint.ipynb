# %% [markdown]
# # Car brand recognition

# %%
#import the needed libraries
import pandas as pd
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import cv2
from keras.utils import to_categorical
from tensorflow.keras.models import Sequential 
from tensorflow.keras.layers import Dense, Dropout, Conv2D, MaxPooling2D, Flatten
from tensorflow.keras import layers
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from keras import metrics
le = LabelEncoder()

# %% [markdown]
# > **Post second modelling** <br>
# **After reducing the categories to be 1/4 of the initial ones, the model still do not perform very good. The reason is most likely the poor quality of the pictures and still there are a a lot of categories - 48, also the fact that the many of the car brands look alike and are not easily distinguished. This notebook will: increase the quaility of the pictures and choose only 10 brands that have more unique and easily recognised cars.**

# %%
#Cars meta is the classification aka the different car models in the dataset
cars_meta = scipy.io.loadmat('data/car_devkit/car_devkit/devkit/cars_meta.mat')
class_names = cars_meta['class_names']  
class_names = np.transpose(class_names)
#Processing train data...
cars_annos = scipy.io.loadmat('data/car_devkit/car_devkit/devkit/cars_train_annos.mat')
annotations = cars_annos['annotations']
annotations = np.transpose(annotations)
annotations = annotations.flatten()

# %% [markdown]
# 1)196 - smart,2) 195 - volvo,3) 185 - tesla,4) 103 - Ferrari,5) 177 - RR,6) 160 - McLaren,7) 173 - Panamera,8) 125 - Hummer,9) 114 - Ford,10) 14-Audi

# %%
brands = [14,103,114,125,160,173,177,185,195,196]

# %%
#get the x and y which in this case are the picture as an array and the car model
x = []
y = []
for annotation in annotations:
    if(annotation[4][0] in brands):
        picture_array = mpimg.imread(f'data/cars_train/cars_train/{annotation[5][0]}')
        picture_array = cv2.resize(picture_array, (64,64)).astype('float32')/255                    
        x.append(picture_array)
        y.append(annotation[4][0])

# %%
#define function that returns the indexes of an item in a list
def list_duplicates_of(seq,item):
    start_at = -1
    locs = []
    while True:
        try:
            loc = seq.index(item,start_at+1)
        except ValueError:
            break
        else:
            locs.append(loc)
            start_at = loc
    return locs

# %%
# since there is little problem with this labels in the data Im fixing them here.
for car in y:
    if car[0] == 195:
        car[0] = 194
for car in y:
    if car[0] == 196:
        car[0] = 195

# %%
#Since in the data all the brand names are the first word of the string I make a new list with only the brand names
brand_names = []
for c in class_names:
    brand_names.append(c[0][0].split(' ')[0])

# %%
brand_names[103] = 'Ferrari'
brand_names[125] = 'HUMMER'
brand_names[173] = 'Porsche Panamera'
brand_names[160] = 'McLaren'
brand_names[177] = 'Rolls Royce'
brand_names[185] = 'Tesla'
brand_names[194] = 'Volvo'
brand_names[195] = 'Smart'

# %%
#Now I make a list with the brands without duplicated values
brand_names_no_dup = list(dict.fromkeys(brand_names))
print( brand_names_no_dup )
# Out:
# ['AM', 'Acura', 'Aston', 'Audi', 'BMW', 'Bentley', 'Bugatti', 'Buick', 'Cadillac', 'Chevrolet', 'Chrysler', 'Daewoo', 'Dodge', 'Eagle', 'FIAT', 'Ferrari', 'Fisker', 'Ford', 'GMC', 'Geo', 'HUMMER', 'Honda', 'Hyundai', 'Infiniti', 'Isuzu', 'Jaguar', 'Jeep', 'Lamborghini', 'Land', 'Lincoln', 'MINI', 'Maybach', 'Mazda', 'McLaren', 'Mercedes-Benz', 'Mitsubishi', 'Nissan', 'Plymouth', 'Porsche', 'Porsche Panamera', 'Rolls-Royce', 'Rolls Royce', 'Spyker', 'Suzuki', 'Tesla', 'Toyota', 'Volkswagen', 'Volvo', 'Smart']

# %%
#The list below contains lists of where each brand appears in the data - aka at which indexes
indexes = []
for brand_no_dup in brand_names_no_dup:
    indexes.append(list_duplicates_of(brand_names, brand_no_dup))

# %%
#This code goes over the Y label and saves the name of the brand into a new list that will be used for modelling
y_new = []
for i in y:
    for index in indexes:
        if i in index:
            y_new.append(brand_names[index[0]])
print(len(y_new))
# Out:
# 426

# %%
#I tried multiple ways to convert the 64,64 array into 64,64,3 but none of them worked so I will have to delete the 18 rows of data where the images are black and white
for t in x:
    if t.shape == (64,64):
        index = x.index(t)
        del x[index]
        del y[index]
# Out:
# <ipython-input-13-54df77b42749>:4: DeprecationWarning: elementwise comparison failed; this will raise an error in the future.
#   index = x.index(t)

# %%
#Now that all the arrays have the same shape we can convert the list into an array and then split the data intro train and test
X = np.array(x)
Y = np.array(y)

# %%
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.2)

# %%
x_train.shape, y_train.shape, x_test.shape, y_test.shape
# Out:
# ((340, 64, 64, 3), (340, 1), (85, 64, 64, 3), (85, 1))

# %%
#Fit the label encoding
le_fitted = le.fit(Y.ravel())

# %%
#Apply label encoding 
y_train_le = le_fitted.transform(y_train)
y_test_le = le_fitted.transform(y_test)

# %%
y_train_one_hot = to_categorical(y_train_le)
y_test_one_hot = to_categorical(y_test_le)

# %%
#Create the models architecture
model = Sequential()

#Add the first layer
model.add(Conv2D(64, (5,5), activation='relu', input_shape=(64,64,3)))

#Add a pooling layer
model.add(MaxPooling2D(pool_size = (2,2)))

#Add a second convolution layer
model.add(Conv2D(64, (5,5), activation='relu'))

#Add a second pooling layer
model.add(MaxPooling2D(pool_size = (2,2)))

#Add a flattening layer - reduce to linear array
model.add(Flatten())

#Create a layer with 1500 neurons
model.add(Dense(1000, activation='relu'))

#Add a dropout layer
model.add(Dropout(0.5))

#Add a layer with 700 neurons
model.add(Dense(500, activation='relu'))

#Add a dropout layer
model.add(Dropout(0.5))

#Add a layer with 300 neurons
model.add(Dense(250, activation='relu'))

#Add a layer with 48 neurons
model.add(Dense(10, activation='softmax'))

# %%
#Compile the model
model.compile(loss = 'categorical_crossentropy',
             optimizer = 'adam',
             metrics = ['accuracy'])

# %%
#Train the model 
hist = model.fit(x_train, y_train_one_hot,
                 batch_size=256,
                 epochs = 100,
                 validation_split = 0.2)
# Out:
# Epoch 1/100
# 2/2 [==============================] - 5s 2s/step - loss: 2.3304 - accuracy: 0.0751 - val_loss: 2.4250 - val_accuracy: 0.0882
# Epoch 2/100
# 2/2 [==============================] - 4s 652ms/step - loss: 2.3514 - accuracy: 0.1124 - val_loss: 2.3172 - val_accuracy: 0.0735
# Epoch 3/100
# 2/2 [==============================] - 4s 657ms/step - loss: 2.3108 - accuracy: 0.0987 - val_loss: 2.3091 - val_accuracy: 0.1471
# Epoch 4/100
# 2/2 [==============================] - 4s 645ms/step - loss: 2.2841 - accuracy: 0.1676 - val_loss: 2.3533 - val_accuracy: 0.0588
# Epoch 5/100
# 2/2 [==============================] - 4s 651ms/step - loss: 2.3039 - accuracy: 0.1250 - val_loss: 2.3946 - val_accuracy: 0.1029
# Epoch 6/100
# 2/2 [==============================] - 4s 642ms/step - loss: 2.2915 - accuracy: 0.1301 - val_loss: 2.3196 - val_accuracy: 0.1618
# Epoch 7/100
# ...

# %%
#Evaluate model on test dataset
model.evaluate(x_test,y_test_one_hot)
# Out:
# 3/3 [==============================] - 0s 144ms/step - loss: 5.2240 - accuracy: 0.3294
# [5.224035739898682, 0.3294117748737335]

# %%
plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'])
plt.show()

# %%
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'])
plt.show()

# %% [markdown]
# # Playing with the predictions
#
# ---

# %%
#Get new test data
#Processing test data...
cars_test_annos = scipy.io.loadmat('data/car_devkit/car_devkit/devkit/cars_test_annos.mat')
annotations_test = cars_test_annos['annotations']
annotations_test = np.transpose(annotations_test)

testing_pictures = []
for annotation in annotations_test:
    picture_array = mpimg.imread(f'data/cars_test/cars_test/{annotation[0][4][0]}')
    picture_array = cv2.resize(picture_array, (64,64)).astype('float32')/255
    testing_pictures.append(picture_array)

# %%
#Visualize a car from the test data to see what is its model - this is an ferrari
plt.imshow(testing_pictures[1086])
plt.title('Ferrari')
plt.show()

# %%
#Get the model predictions on the image above
predictions = model.predict(np.array([testing_pictures[1086]]))
#Sort the predictions from least to greatest
list_index = list(range(0,10))
p = predictions

for i in range(10):
    for j in range(10):
        if p[0][list_index[i]] > p[0][list_index[j]]:
            temp = list_index[i]
            list_index[i] = list_index[j]
            list_index[j] = temp
print(list_index)
# Out:
# [1, 2, 9, 4, 7, 0, 3, 8, 5, 6]

# %%
#print first 5 most likely classes by predictions
for i in range(5):
    print(brand_names[le_fitted.classes_[list_index[i]]], ':', round(predictions[0][list_index[i]] * 100), '%')
# Out:
# Ferrari : 100 %
# Ford : 0 %
# Smart : 0 %
# McLaren : 0 %
# Tesla : 0 %

# %%
#Visualize a car from the test data to see what is its model - this is an Ford
plt.imshow(testing_pictures[1709])
plt.title('Ford')
plt.show()

# %%
#Get the model predictions on the image above
predictions = model.predict(np.array([testing_pictures[1709]]))
#Sort the predictions from least to greatest
list_index = list(range(0,10))
p = predictions

for i in range(10):
    for j in range(10):
        if p[0][list_index[i]] > p[0][list_index[j]]:
            temp = list_index[i]
            list_index[i] = list_index[j]
            list_index[j] = temp
print(list_index)
# Out:
# [2, 3, 8, 0, 7, 6, 5, 9, 4, 1]

# %%
#print first 5 most likely classes by predictions
for i in range(5):
    print(brand_names[le_fitted.classes_[list_index[i]]], ':', round(predictions[0][list_index[i]] * 100), '%')
# Out:
# Ford : 100 %
# HUMMER : 0 %
# Volvo : 0 %
# Audi : 0 %
# Tesla : 0 %

# %%
#Visualize a car from the test data to see what is its model - this is an HUMMER
plt.imshow(testing_pictures[3588])
plt.title('Hummer')
plt.show()

# %%
#Get the model predictions on the image above
predictions = model.predict(np.array([testing_pictures[3588]]))
#Sort the predictions from least to greatest
list_index = list(range(0,10))
p = predictions

for i in range(10):
    for j in range(10):
        if p[0][list_index[i]] > p[0][list_index[j]]:
            temp = list_index[i]
            list_index[i] = list_index[j]
            list_index[j] = temp
print(list_index)
# Out:
# [7, 2, 3, 4, 6, 5, 0, 8, 9, 1]

# %%
#print first 5 most likely classes by predictions
for i in range(5):
    print(brand_names[le_fitted.classes_[list_index[i]]], ':', round(predictions[0][list_index[i]] * 100), '%')
# Out:
# Tesla : 39 %
# Ford : 22 %
# HUMMER : 12 %
# McLaren : 7 %
# Rolls Royce : 7 %

# %%
#Visualize a car from the test data to see what is its model - this is an Smart 
plt.imshow(testing_pictures[4188])
plt.title('Smart')
plt.show()

# %%
#Get the model predictions on the image above
predictions = model.predict(np.array([testing_pictures[4188]]))
#Sort the predictions from least to greatest
list_index = list(range(0,10))
p = predictions

for i in range(10):
    for j in range(10):
        if p[0][list_index[i]] > p[0][list_index[j]]:
            temp = list_index[i]
            list_index[i] = list_index[j]
            list_index[j] = temp

# %%
#print first 5 most likely classes by predictions
for i in range(5):
    print(brand_names[le_fitted.classes_[list_index[i]]], ':', round(predictions[0][list_index[i]] * 100), '%')
# Out:
# Audi : 53 %
# Smart : 42 %
# Tesla : 3 %
# Porsche Panamera : 1 %
# Ferrari : 1 %

# %% [markdown]
# The Audi I trained the model with is R8 which is rather short like this Smart and thats why the model is a bit indecisive between the two brands

# %%
#Visualize a car from the test data to see what is its model - this is an Audi which is red (most of the ferraris are red)
plt.imshow(testing_pictures[4584])
plt.title('Audi')
plt.show()

# %%
#Get the model predictions on the image above
predictions = model.predict(np.array([testing_pictures[4584]]))
#Sort the predictions from least to greatest
list_index = list(range(0,10))
p = predictions

for i in range(10):
    for j in range(10):
        if p[0][list_index[i]] > p[0][list_index[j]]:
            temp = list_index[i]
            list_index[i] = list_index[j]
            list_index[j] = temp
print(list_index)
# Out:
# [1, 7, 9, 4, 0, 2, 8, 3, 5, 6]

# %%
#print first 5 most likely classes by predictions
for i in range(5):
    print(brand_names[le_fitted.classes_[list_index[i]]], ':', round(predictions[0][list_index[i]] * 100), '%')
# Out:
# Ferrari : 98 %
# Tesla : 2 %
# Smart : 0 %
# McLaren : 0 %
# Audi : 0 %

# %% [markdown]
# Expectedly because of the not many records in the data and the fact that most of the ferraris are red it thinks that this Audi is a Ferrari

# %%
#Visualize a car from the test data to see what is its model - this is another audi in red paint
plt.imshow(testing_pictures[4680])
plt.title('Audi')
plt.show()

# %%
#Get the model predictions on the image above
predictions = model.predict(np.array([testing_pictures[4680]]))
#Sort the predictions from least to greatest
list_index = list(range(0,10))
p = predictions

for i in range(10):
    for j in range(10):
        if p[0][list_index[i]] > p[0][list_index[j]]:
            temp = list_index[i]
            list_index[i] = list_index[j]
            list_index[j] = temp
print(list_index)
# Out:
# [1, 9, 7, 4, 2, 0, 8, 3, 5, 6]

# %%
#print first 5 most likely classes by predictions
for i in range(5):
    print(brand_names[le_fitted.classes_[list_index[i]]], ':', round(predictions[0][list_index[i]] * 100), '%')
# Out:
# Ferrari : 65 %
# Smart : 28 %
# Tesla : 6 %
# McLaren : 1 %
# Ford : 0 %

# %% [markdown]
# Second time a red car is predicted as a Ferrari which means that the color is pattern with big weight in this small dataset. Still the model is only 65% sure which means that the shape of the car also matters.

# %%
#Visualize a car from the test data to see what is its model - this is a Rolls Royce
plt.imshow(testing_pictures[5776])
plt.title('Rolls Royce')
plt.show()

# %%
#Get the model predictions on the image above
predictions = model.predict(np.array([testing_pictures[5776]]))
#Sort the predictions from least to greatest
list_index = list(range(0,10))
p = predictions

for i in range(10):
    for j in range(10):
        if p[0][list_index[i]] > p[0][list_index[j]]:
            temp = list_index[i]
            list_index[i] = list_index[j]
            list_index[j] = temp
print(list_index)
# Out:
# [6, 8, 5, 9, 7, 0, 2, 3, 4, 1]

# %%
#print first 5 most likely classes by predictions
for i in range(5):
    print(brand_names[le_fitted.classes_[list_index[i]]], ':', round(predictions[0][list_index[i]] * 100), '%')
# Out:
# Rolls Royce : 66 %
# Volvo : 28 %
# Porsche Panamera : 3 %
# Smart : 3 %
# Tesla : 0 %

# %%
#Visualize a car from the test data to see what is its model - this is Mclaren
plt.imshow(testing_pictures[6965])
plt.title('McLaren')
plt.show()

# %%
#Get the model predictions on the image above
predictions = model.predict(np.array([testing_pictures[6965]]))
#Sort the predictions from least to greatest
list_index = list(range(0,10))
p = predictions

for i in range(10):
    for j in range(10):
        if p[0][list_index[i]] > p[0][list_index[j]]:
            temp = list_index[i]
            list_index[i] = list_index[j]
            list_index[j] = temp
print(list_index)
# Out:
# [4, 1, 9, 7, 2, 0, 3, 8, 5, 6]

# %%
#print first 5 most likely classes by predictions
for i in range(5):
    print(brand_names[le_fitted.classes_[list_index[i]]], ':', round(predictions[0][list_index[i]] * 100), '%')
# Out:
# McLaren : 100 %
# Ferrari : 0 %
# Smart : 0 %
# Tesla : 0 %
# Ford : 0 %

# %% [markdown]
# >**Conclusion<br>
# After using only 10 brands the accuracy of the model improved drastically - 32%. However because the data consist of less than 500 records I cannot still expect it to work flawlessly, if I had more records in the data I'm confident that the model can peform much better. For example, now the model identifies red cars instantly as ferraris because almost all of them in data are red which might be fixed if the other brands also had pictures with red paint. The increased quality of the pictures also definitely contributed to the improvement of the model. A possible continuation for the next itteration is to make my own web scraper for cars and possibly go to any big website for cars and get the data myself rather than working with already made dataset.**
